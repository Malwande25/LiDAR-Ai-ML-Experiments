# %%
import pandas as pd
import matplotlib.pyplot as plt

# Loading the logged CSV file
df = pd.read_csv("sf45b_log.csv")

# Quick check
print(df.head())

# Example plot
plt.figure(figsize=(10,5))
plt.scatter(df["yaw_deg"], df["distance_m"], s=10)
plt.xlabel("Yaw (degrees)")
plt.ylabel("Distance (m)")
plt.title("LiDAR Scan")
plt.show()
# Out:
#       timestamp  distance_m  yaw_deg
# 0  1.758274e+09        0.07    70.80
# 1  1.758274e+09        0.07    73.50
# 2  1.758274e+09        0.07    78.90
# 3  1.758274e+09        0.07    83.85
# 4  1.758274e+09        0.07    89.25
